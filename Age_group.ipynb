# %%
import numpy as np, scipy.stats as st
import pandas as pd
import seaborn as sns
import scipy as sp
import scipy.stats
import matplotlib.pyplot as plt

# %%
veterans_df = pd.read_csv("Vet Suicides 2005-2014 (Age Groups).csv") 
veterans_age_df = pd.read_csv("veteran_suicide_age_2005-2008.csv") 
df = veterans_df.head(7)
del df['Unnamed: 11']
df2=df.set_index("age range")

# %%
# Calculate the mean and standard error
avg_18_29_mean = (df2.loc["18-29"]).mean()
avg_30_39_mean = (df2.loc["30-39"]).mean()
avg_40_49_mean = (df2.loc["40-49"]).mean()
avg_50_59_mean = (df2.loc["50-59"]).mean()
avg_60_69_mean = (df2.loc["60-69"]).mean()
avg_70_79_mean = (df2.loc["70-79"]).mean()
avg_80_mean = (df2.loc["80+"]).mean()

std_18_29_mean = st.stats.sem(df2.loc["18-29"])
std_30_39_mean = st.stats.sem(df2.loc["30-39"])
std_40_49_mean = st.stats.sem(df2.loc["40-49"])
std_50_59_mean = st.stats.sem(df2.loc["50-59"])
std_60_69_mean = st.stats.sem(df2.loc["60-69"])
std_70_79_mean = st.stats.sem(df2.loc["70-79"])
std_80_mean = st.stats.sem(df2.loc["80+"])

data = [['18-29',avg_18_29_mean,std_18_29_mean],['30-39',avg_30_39_mean,std_30_39_mean],['40-49',avg_40_49_mean,std_40_49_mean],['50-59',avg_50_59_mean,std_50_59_mean],['60-69',avg_60_69_mean,std_60_69_mean],['70-79',avg_70_79_mean,std_70_79_mean],['80+',avg_80_mean,std_80_mean]]
df1 = pd.DataFrame(data,columns=['Age Group','Mean','STD'])

# %%
N = 7
fig, ax = plt.subplots()
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars


recs1 = ax.bar(ind,df1['Mean'], width, color='darkblue', yerr=2*df1['STD'])

# add some text for labels, title and axes ticks
ax.set_ylabel('Suicide Rate')
ax.set_xlabel('Age Group')
ax.set_title('Suicide Rate by Age Group')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('18-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80+'))
plt.ylim(0,70,10)
plt.legend()
sns.set(rc={'figure.figsize':(8,5)})
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.25*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(recs1)
plt.show()

# %%
veterans_age_df.head(7)
# Out:
#   age_range  vet_suicide_2005  vet_suicide_2006  vet_suicide_2007  \
# 0     18-29                12                11                23
# 1     30-39                71                83                92
# 2     40-49               183               195               185
# 3     50-59               486               453               495
# 4     60-69               385               450               525
# 5     70-79               494               565               485
# 6       80+               808               712               595
#
#    vet_suicide_2008  Nonvet_suicide_2005  Nonvet_suicide_2006  \
# 0                15                   86                  552
# 1                83                  865                  882
# 2               185                 1008                  994
# 3               487                 1092                 1012
# 4               553                  495                  321
# 5               462                  427                  196
# ...

# %%
df = veterans_age_df.set_index('age_range')

std_18_29 = st.stats.sem(d.loc['18-29','vet_suicide_2005':'vet_suicide_2008'])/4
std_30_39 = st.stats.sem(d.loc['30-39','vet_suicide_2005':'vet_suicide_2008'])/4
std_40_49 = st.stats.sem(d.loc['40-49','vet_suicide_2005':'vet_suicide_2008'])/4
std_50_59 = st.stats.sem(d.loc['50-59','vet_suicide_2005':'vet_suicide_2008'])/4
std_60_69 = st.stats.sem(d.loc['60-69','vet_suicide_2005':'vet_suicide_2008'])/4
std_70_79 = st.stats.sem(d.loc['70-79','vet_suicide_2005':'vet_suicide_2008'])/4
std_80 = st.stats.sem(d.loc['80+','vet_suicide_2005':'vet_suicide_2008'])/4 

std_18_29_nonvet = st.stats.sem(d.loc['18-29','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4
std_30_39_nonvet = st.stats.sem(d.loc['30-39','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4
std_40_49_nonvet = st.stats.sem(d.loc['40-49','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4
std_50_59_nonvet = st.stats.sem(d.loc['50-59','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4
std_60_69_nonvet = st.stats.sem(d.loc['60-69','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4
std_70_79_nonvet = st.stats.sem(d.loc['70-79','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4
std_80_nonvet = st.stats.sem(d.loc['80+','Nonvet_suicide_2005':'Nonvet_suicide_2008'])/4

# %%
vet_suc_age_list = (veterans_age_df['vet_suicide_2005']+veterans_age_df['vet_suicide_2006']+veterans_age_df['vet_suicide_2007']+veterans_age_df['vet_suicide_2008'])
vet_suc_pop = veterans_age_df['vet_pop_16sates']

nonvet_suc_age_list = (veterans_age_df['Nonvet_suicide_2005']+veterans_age_df['Nonvet_suicide_2006']+veterans_age_df['Nonvet_suicide_2007']+veterans_age_df['Nonvet_suicide_2008'])
nonvet_suc_pop = veterans_age_df['nonvet_pop_16sates']

# %%
data = [['18-29',vet_suc_age_list[0],nonvet_suc_age_list[0],vet_suc_pop[0],nonvet_suc_pop[0],std_18_29,std_18_29_nonvet],['30-39',vet_suc_age_list[1],nonvet_suc_age_list[1],vet_suc_pop[1],nonvet_suc_pop[1],std_30_39,std_30_39_nonvet],['40-49',vet_suc_age_list[2],nonvet_suc_age_list[2],vet_suc_pop[2],nonvet_suc_pop[2],std_40_49,std_40_49_nonvet],['50-59',vet_suc_age_list[3],nonvet_suc_age_list[3],vet_suc_pop[3],nonvet_suc_pop[3],std_50_59,std_50_59_nonvet],['60-69',vet_suc_age_list[4],nonvet_suc_age_list[4],vet_suc_pop[4],nonvet_suc_pop[4],std_60_69,std_60_69_nonvet],['70-79',vet_suc_age_list[5],nonvet_suc_age_list[5],vet_suc_pop[5],nonvet_suc_pop[5],std_70_79,std_70_79_nonvet],['80+',vet_suc_age_list[6],nonvet_suc_age_list[6],vet_suc_pop[6],nonvet_suc_pop[6],std_80,std_80_nonvet]]
df3 = pd.DataFrame(data,columns=['Age Group','Total_Vet_Sucide','Total_Nonvet_Suicide','Veterans Population','Non Veterans Population','Vet Std error','Non-Vet Std error'])
df4 = df3.set_index('Age Group')
vet_rate = ((df4['Total_Vet_Sucide']/df4['Veterans Population'])*100000)/4
non_vet_rate = ((df4['Total_Nonvet_Suicide']/df4['Non Veterans Population'])*100000)/4
vet_rate.round(2)
non_vet_rate.round(2)
df3
# Out:
#   Age Group  Total_Vet_Sucide  Total_Nonvet_Suicide  Veterans Population  \
# 0     18-29                61                  2307                65974
# 1     30-39               329                  3490               302379
# 2     40-49               748                  4068               544281
# 3     50-59              1921                  4249               808175
# 4     60-69              1913                  2241              1412933
# 5     70-79              2006                  1065              1094061
# 6       80+              2936                   595              1269990
#
#    Non Veterans Population  Vet Std error  Non-Vet Std error
# 0                  4442150       1.487360           8.879620
# 1                  4997418       1.077105           1.386317
# 2                  4804281       0.677003           2.917262
# 3                  4852566       4.807221           4.472573
# 4                  2969481       8.784678           9.992380
# ...

# %%
N = 7

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind,vet_rate, width, color='darkblue', yerr=0.45*df3['Vet Std error'])


rects2 = ax.bar(ind+width, non_vet_rate, width, color='skyblue', yerr=0.45*df3['Non-Vet Std error'])

# add some text for labels, title and axes ticks
ax.set_ylabel('Suicide Rate per 100,000 Population')
ax.set_xlabel('Age Group')
ax.set_title('Suicide Rate by Age Group')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('18-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80+'))
plt.ylim(0,90,10)
ax.legend((rects1[0], rects2[0]), ('Veteran', 'Non-Veteran'))
sns.set(rc={'figure.figsize':(12,7)})

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.25*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()
